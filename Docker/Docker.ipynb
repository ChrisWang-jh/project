# %% [markdown]
# # Docker

# %%
docker pull docker.io/library/nginx:latest
# docker pull 仓库名(官方仓库可省略)/作者名/image名：版本号

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# hub.docker.com
# docker.fxxk.dedyn.io 国内镜像站

# %% [markdown]
# docker run n8n 使用镜像创建并运行一个容器（run后接镜像名字或者id）
#     docker run -d 容器在后台进行
#     docker run -p 绑定端口
#     docker run -v 挂载卷（数据持久化保存）

# %% [markdown]
# docker ps 展示正在运行的容器（percess status查看进程状况）
# ![image.png](attachment:image.png)

# %% [markdown]
# docker rm 删除容器
# docker rmi 删除容器的image
